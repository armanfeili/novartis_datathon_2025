# %%
import pandas as pd
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.utils import load_config
from src.models.lgbm_model import LGBMModel

# %load_ext autoreload
# %autoreload 2

# %%
# Load Config
model_config = load_config('../configs/model_lgbm.yaml')
model = LGBMModel(model_config)

# %%
# Test Training on Dummy Data
# X = ...
# y = ...
# model.fit(X, y)
