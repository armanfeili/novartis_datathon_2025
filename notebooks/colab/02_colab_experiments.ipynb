# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('../..'))

from src.train import main

# %%
# Run Training
# !python ../../src/train.py --model-config ../../configs/model_lgbm.yaml
