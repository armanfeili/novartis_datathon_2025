# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.utils import load_config
from src.data import DataManager

# %load_ext autoreload
# %autoreload 2

# %%
# Load Data
config = load_config('../configs/data.yaml')
# Adjust paths for notebook execution
config['local']['raw_dir'] = '../data/raw'
config['local']['interim_dir'] = '../data/interim'
config['local']['processed_dir'] = '../data/processed'

dm = DataManager(config)
raw_data = dm.load_raw_data()

# %%
# Inspect Data
for name, df in raw_data.items():
    print(f"Dataset: {name}")
    print(df.info())
    print(df.head())
    print("-" * 50)
